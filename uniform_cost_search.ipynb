# %%
# uniform cost function
# returns the minimum cost (Bonus: returns path to minimum cost as well)
def  uniform_cost_search(start, goal, graph, cost):
    answer = {node: {'cost': float('inf'), 'path': []} for node in goal}


    from queue import PriorityQueue
    q = PriorityQueue()
    q.put((0,start))
    explored = {node: False for node in range(len(graph))}
    current = None
    paths = {i: [0] for i in range(30)}
    #iteratively loop through the priority queue
    while not q.empty():
        current = q.get()
        print("=================================")
        if not explored[current[1]]:
            print(f"exploring node: {current[1]}")
            for node in graph[current[1]]:
                #print(f"visiting child, node: {node}")
                newCost = current[0] + cost[(current[1], node)]
                paths[node] = paths[current[1]][:]
                paths[node].append(node)
                q.put((newCost, node))
                #print(f"cumulative cost to get to node: {node}, is {current[0]} + {cost[(current[1], node)]} = {current[0] + cost[(current[1], node)]}")
                #print(f"path taken was: {paths[node]}")
            if current[1] in goal:
                answer[current[1]] = {'cost': current[0], 'path': paths[current[1]]}
                #print(f"FOUND A GOAL: {current[1]}")
            explored[current[1]] = True
            #print(f"successfully explored node: {current[1]}")
            #print("=================================")

        else:
            pass
            #print(f"node: {current[1]} has already been explored")
    
#     **************************************
#     ******** Write your code here ********
#     **************************************

    return answer
 
# main function
if __name__ == '__main__':
     
    # create a graph with no more than 30 nodes
    graph, cost = [[] for i in range(30)], {}
 
    # add edges to the graph
    graph[0].append(4)
    graph[0].append(5)
    graph[0].append(16)
    graph[2].append(1)
    graph[3].append(1)
    graph[4].append(2)
    graph[4].append(3)
    graph[4].append(5)
    graph[5].append(8)
    graph[5].append(18)
    graph[6].append(3)
    graph[6].append(7)
    graph[8].append(16)
    graph[8].append(17)
    graph[16].append(17)
    graph[18].append(6)
    
 
    # add cost to each edge
    cost[(0, 4)] = 3
    cost[(0, 5)] = 9
    cost[(0, 16)] = 1
    cost[(2, 1)] = 2
    cost[(3, 1)] = 2
    cost[(4, 2)] = 1
    cost[(4, 3)] = 8
    cost[(4, 5)] = 2
    cost[(5, 8)] = 3
    cost[(5, 18)] = 2
    cost[(6, 3)] = 3
    cost[(6, 7)] = 2
    cost[(8, 16)] = 4
    cost[(8, 17)] = 4
    cost[(16, 17)] = 15
    cost[(18, 6)] = 1
    
    # set start state 
    start = 0
    
    # set goal state, there can be multiple goal states
    goal = [7]
    
    # call uniform_search_cost function to get the minimum cost to reach gaol. Bonus points for path
    # ****** You have to implement this function *****
    min_cost_info = uniform_cost_search(start, goal, graph, cost)

    for node, info in min_cost_info.items():
        print(f'Minimum cost from {start} to {node} is {info["cost"]}')
      
    #   **** Bonus ****
    print(f'Path: {info["path"]}')
# Out:
# ...
# exploring node: 0
# ...
# exploring node: 16
# ...
# exploring node: 4
# ...
# exploring node: 2
# ...
# exploring node: 5
# ...
# exploring node: 1
# ...
# exploring node: 18
# ...
# exploring node: 6
# ...
# exploring node: 8
# ...
# exploring node: 7
# ...
# exploring node: 3
# ...
# exploring node: 17
# ...
# Minimum cost from 0 to 7 is 10
# Path: [0, 4, 5, 18, 6, 7]
